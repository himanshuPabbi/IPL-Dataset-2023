# %% [markdown]
# # Project Title : IPL 2023 Dataset (EDA)
# ## Quantitative
# ## A quantitative variable is a variable that reflects a notion of magnitude, that is, if the values it can take are numbers. A quantitative variable represents thus a measure and is numerical.
#
# ## Quantitative variables are divided into two types: discrete and continuous. The difference is explained in the following two sections.
#
# ## Discrete
# ## Quantitative discrete variables are variables for which the values it can take are countable and have a finite number of possibilities. The values are often (but not always) integers. Here are some examples of discrete variables:
#
# ## Continuous
# ## On the other hand, quantitative continuous variables are variables for which the values are not countable and have an infinite number of possibilities. For example: Age,Weight,Height
#
# ## Qualitative
# ## In opposition to quantitative variables, qualitative variables (also referred as categorical variables or factors in R) are variables that are not numerical and which values fits into categories.
#
# ## In other words, a qualitative variable is a variable which takes as its values modalities, categories or even levels, in contrast to quantitative variables which measure a quantity on each individual.
#
# ## Qualitative variables are divided into two types: nominal and ordinal.
# ## Nominal
# ## A qualitative nominal variable is a qualitative variable where no ordering is possible or implied in the levels.
#
# ## For example, the variable gender is nominal because there is no order in the levels (no matter how many levels you consider for the gender—only two with female/male, or more than two with female/male/ungendered/others, levels are unordered). Eye color is another example of a nominal variable because there is no order among blue, brown or green eyes.
#
# ## Ordinal
# ## On the other hand, a qualitative ordinal variable is a qualitative variable with an order implied in the levels. For instance, if the severity of road accidents has been measured on a scale such as light, moderate and fatal accidents, this variable is a qualitative ordinal variable because there is a clear order in the levels.
#
# ## Another good example is health, which can take values such as poor, reasonable, good, or excellent. Again, there is a clear order in these levels so health is in this case a qualitative ordinal variable
#
# ## Nominal :
# 1. batsman
# 2. team
# 3. out_by
# 4. city
# 5. date_of_match
# 6. venue
# 7. result
# 8. result_margin
# 9. eliminator
# 10. Umpire 1
# 11. Umpire 2
# 12. Bowler
# 13. Team
# 14. out_by
# 15. Home_team
# 16. Away_team
#
# ## Ordinal :
# 17. toss_winner
# 18. winner
# 19. man_of_match
#
# ## DISCRETE:
# 20. match_no
# 21. Run
# 22. Ball
# 23. 4s
# 24. 6s
# 25. Home_team_run
# 26. Home_team_wickets
# 27. Away_team_run
# 28. Home_team_run
# 29. Home_team_wickets
# 30. Home_team
# 31. Away_team
# 32. Run
# 33. Ball
# 34. 4s
# 35. 6s
#
#
# ## Continuoue
# 36. Home_team_over
# 37. Away_team_over
# 38. toss_winner
# 39. winner
# 40. man_of_match

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
IPL2023_Batsman_df=pd.read_csv('IPL2023_Batsman.csv',encoding="latin-1")

# %%
IPL2023_Batsman_df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by
# 0        Mohammed Shami
# 1        Alzarri Joseph
# 2           Rashid Khan
# ...

# %%
IPL2023_Match_Scoreboard_df=pd.read_csv("IPL2023_Match_Scoreboard.csv")

# %%
IPL2023_Match_Scoreboard_df
# Out:
#     match_no  Home_team_run  Home_team_wickets  Home_team_over  Away_team_run  \
# 0          1            182                  5            19.2            178
# 1          2            191                  5            20.0            146
# 2          3            193                  6            20.0            143
# 3          4            131                  8            20.0            203
# 4          5            172                  2            16.2            171
# ..       ...            ...                ...             ...            ...
# 65        66            187                  5            20.0            189
# 66        67            146                  9            20.0            223
# 67        68            175                  7            20.0            176
# 68        69            201                  2            18.0            200
# 69        70            197                  5            20.0            198
#
# ...

# %%
df=IPL2023_Batsman_df.merge(IPL2023_Match_Scoreboard_df,how="inner")

# %%
df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by  Home_team_run  Home_team_wickets  Home_team_over  \
# ...

# %%
IPL2023_Matches_df=pd.read_csv("IPL2023_Matches.csv",encoding='latin-1')

# %%
IPL2023_Matches_df
# Out:
#     match_no        city date_of_match  \
# 0          1   Ahmedabad     3/31/2023
# 1          2      Mohali      4/1/2023
# 2          3     Lucknow      4/1/2023
# 3          4   Hyderabad      4/2/2023
# 4          5   Bengaluru      4/2/2023
# ..       ...         ...           ...
# 65        66  Dharamsala     5/19/2023
# 66        67       Delhi     5/20/2023
# 67        68     Kolkata     5/20/2023
# 68        69     Mumbai      5/21/2023
# 69        70   Bengaluru     5/21/2023
#
#                                                 venue  \
# 0                               Narendra Modi Stadium
# 1        Punjab Cricket Association IS Bindra Stadium
# 2   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 3                  Rajiv Gandhi International Stadium
# 4                               M.Chinnaswamy Stadium
# ..                                                ...
# 65       Himachal Pradesh Cricket Association Stadium
# ...

# %%
df=df.merge(IPL2023_Matches_df,how="inner")

# %%
df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by  Home_team_run  Home_team_wickets  ...  \
# ...

# %%
IPL2023_Bowler=pd.read_csv('IPL2023_Bowler.csv')

# %%
IPL2023_Bowler
# Out:
#      match_no             Bowler                         team  over  run  \
# 0           1     Mohammed Shami               Gujarat Titans   4.0   29
# 1           1      Hardik Pandya               Gujarat Titans   3.0   28
# 2           1      Joshua Little               Gujarat Titans   4.0   41
# 3           1        Rashid Khan               Gujarat Titans   4.0   26
# 4           1     Alzarri Joseph               Gujarat Titans   4.0   33
# ..        ...                ...                          ...   ...  ...
# 848        70      Wayne Parnell  Royal Challengers Bangalore   3.1   42
# 849        70  Vijaykumar Vyshak  Royal Challengers Bangalore   4.0   40
# 850        70    Himanshu Sharma  Royal Challengers Bangalore   3.0   28
# 851        70      Harshal Patel  Royal Challengers Bangalore   4.0   29
# 852        70  Michael Bracewell  Royal Challengers Bangalore   1.0   16
#
#      wicket  No_ball   ECO
# 0         2        1   7.3
# 1         0        0   9.3
# ...

# %%
df=df.merge(IPL2023_Bowler,how="inner")

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6651 entries, 0 to 6650
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   match_no           6651 non-null   int64
#  1   Batsman            6651 non-null   object
#  2   team               6651 non-null   object
#  3   Run                6651 non-null   int64
#  4   Ball               6651 non-null   int64
#  5   4s                 6651 non-null   int64
#  6   6s                 6651 non-null   int64
#  7   out_by             6651 non-null   object
#  8   Home_team_run      6651 non-null   int64
#  9   Home_team_wickets  6651 non-null   int64
#  10  Home_team_over     6651 non-null   float64
#  11  Away_team_run      6651 non-null   int64
#  12  Away_team_wickets  6651 non-null   int64
#  13  Away_team_over     6651 non-null   float64
#  14  city               6651 non-null   object
#  15  date_of_match      6651 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['match_no', 'Batsman', 'team', 'Run', 'Ball', '4s', '6s', 'out_by',
#        'Home_team_run', 'Home_team_wickets', 'Home_team_over', 'Away_team_run',
#        'Away_team_wickets', 'Away_team_over', 'city', 'date_of_match', 'venue',
#        'Home_team', 'Away_team', 'toss_winner', 'winner', 'man_of_the_match',
#        'result', 'result_margin', 'eliminator', 'umpire1', 'umpire2', 'Bowler',
#        'over', 'run', 'wicket', 'No_ball', 'ECO'],
#       dtype='object')

# %%
df.describe()
# Out:
#           match_no          Run         Ball           4s           6s  \
# count  6651.000000  6651.000000  6651.000000  6651.000000  6651.000000
# mean     34.672681    20.826492    14.662156     1.860021     0.963013
# std      20.019165    23.068677    13.641180     2.522163     1.578850
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%      17.000000     3.000000     4.000000     0.000000     0.000000
# 50%      34.000000    12.000000    10.000000     1.000000     0.000000
# 75%      52.000000    30.000000    21.000000     3.000000     1.000000
# max      70.000000   124.000000    66.000000    16.000000    10.000000
#
#        Home_team_run  Home_team_wickets  Home_team_over  Away_team_run  \
# count    6651.000000        6651.000000     6651.000000    6651.000000
# mean      173.585326           6.437378       19.396346     174.267178
# std        32.209564           2.228478        1.486721      31.969003
# ...

# %%
df.drop_duplicates()
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
sns.boxplot(df['Run'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Run'>

# %%
q1=df['Run'].quantile(0.25)

# %%
q3=df['Run'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Run']>lower) & (df['Run']<upper)]

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
sns.boxplot(df['Ball'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ball'>

# %%
q1=df['Ball'].quantile(0.25)

# %%
q3=df['Ball'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Ball']>lower) & (df['Ball']<upper)]

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
sns.boxplot(df['Ball'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ball'>

# %%
sns.boxplot(df['result_margin'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='result_margin'>

# %%
q1=df['result_margin'].quantile(0.25)

# %%
q3=df['result_margin'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['result_margin']>lower) & (df['result_margin']<upper)]

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
sns.boxplot(df['ECO'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ECO'>

# %%
q1=df['ECO'].quantile(0.25)

# %%
q3=df['ECO'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['ECO']>lower) & (df['ECO']<upper)]

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
sns.boxplot(df['ECO'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ECO'>

# %%
sns.boxplot(df['Away_team_run'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Away_team_run'>

# %%
sns.boxplot(df['4s'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='4s'>

# %%
q1=df['4s'].quantile(0.25)

# %%
q3=df['4s'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['4s']>lower) & (df['4s']<upper)]

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
sns.boxplot(df['6s'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='6s'>

# %%
q1=df['6s'].quantile(0.25)

# %%
q3=df['6s'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['6s']>lower) & (df['6s']<upper)]

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
df.head(10)
# Out:
#     match_no       Batsman                 team  Run  Ball  4s  6s  \
# 0          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1     Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1     Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1     Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1     Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1     Moeen Ali  Chennai Super Kings   23    17   4   1
#
#             out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# 0   Mohammed Shami            182                  5  ...              5
# 1   Mohammed Shami            182                  5  ...              5
# ...

# %%
plt.figure(figsize=(20,15))
sns.countplot(df['man_of_the_match'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.groupby('man_of_the_match').size().sort_values(ascending=False)
# Out:
# man_of_the_match
# Ravindra Jadeja        216
# Faf du Plessis         208
# Varun Chakaravarthy    194
# Yashasvi Jaiswal       170
# Shubman Gill           168
# Nicholas Pooran        164
# Devon Conway           150
# Mohit Sharma           145
# Virat Kohli            138
# Rashid Khan            131
# Marcus Stoinis         130
# Suryakumar Yadav       124
# Krunal Pandya          119
# Rinku Singh            118
# Prabhsimran Singh      110
# Axar Patel             109
# Ishant Sharma          105
# Sikandar Raza          104
# Mark Wood               86
# Glenn Maxwell           84
# Shimron Hetmyer         83
# Andre Russell           80
# Arshdeep Singh          80
# Sam Curran              79
# Matheesha Pathirana     78
# Moeen Ali               78
# Ravichandran Ashwin     78
# Mohammed Siraj          78
# Mohammed Shami          75
# Sai Sudharsan           75
# Venkatesh Iyer          72
# Shikhar Dhawan          72
# Rohit Sharma            69
# ...

# %% [markdown]
# # Observations:
# 1. Ravindra Jadeja is man_of_the_match maximum number of times
# 2. Devdutt Padikkal is man_of_the_match minimum number of times

# %%
label_df=df.groupby('man_of_the_match').size().sort_values(ascending=False).index

# %%
val_df=df.groupby('man_of_the_match').size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['winner'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
label_df=df.groupby('winner').size().sort_values(ascending=False).index

# %%
val_df=df.groupby('winner').size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Gujarat Titans wins maximum number of match
# 2. Sunrisers Hyderabad wins minimum number of times

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df['toss_winner'])
plt.xticks(rotation=90)
plt.show()

# %%
label_df=df.groupby('toss_winner').size().sort_values(ascending=False).index

# %%
val_df=df.groupby('toss_winner').size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Rajasthan Royals wins toss maximum number of times
# 2. Lucknow Super Giants wins toss minimum number of times

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['venue'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
label_df=df.groupby('venue').size().sort_values(ascending=False).index

# %%
val_df=df.groupby('venue').size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of matches were held on Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium.
# 2. Minimum number of matches were held on Barsapara Cricket Stadium.

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['result_margin'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='result_margin', ylabel='count'>

# %%
label_df=df.groupby('result_margin').size().sort_values(ascending=False).index

# %%
val_df=df.groupby('result_margin').size().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=df.groupby(['Batsman','out_by','team']).size().sort_values(ascending=False).index

# %%
label_df
# Out:
# MultiIndex([(    'Kuldeep Yadav',        'Not Out', ...),
#             (    'Shahrukh Khan',        'Not Out', ...),
#             (         'MS Dhoni',        'Not Out', ...),
#             (    'Cameron Green',        'Not Out', ...),
#             (    'Rahul Tewatia',        'Not Out', ...),
#             (        'Tim David',        'Not Out', ...),
#             (     'David Miller',        'Not Out', ...),
#             (       'Anuj Rawat',        'Not Out', ...),
#             ('Bhuvneshwar Kumar',        'Not Out', ...),
#             (     'Ravi Bishnoi',        'Not Out', ...),
#             ...
#             (   'Dinesh Karthik',   'Chris Jordan', ...),
#             (      'Dhruv Jurel', 'Riley Meredith', ...),
#             (   'Mitchell Marsh',      'Mark Wood', ...),
#             (      'Dhruv Jurel', 'Mohammed Shami', ...),
#             (      'Dhruv Jurel',     'Avesh Khan', ...),
#             (    'Sai Sudharsan', 'Arshdeep Singh', ...),
# ...

# %%
val_df=df.groupby(['Batsman','out_by','team']).size().sort_values(ascending=False).values

# %%
val_df
# Out:
# array([45, 34, 34, 31, 29, 25, 21, 19, 19, 18, 18, 18, 17, 16, 16, 15, 15,
#        15, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 12, 12,
#        12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 11,
#        11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 10,  8,  8,  8,
#         8,  8,  8,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,
#         7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,
#         7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,
#         7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,
#         7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,
#         7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  6,
#         6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,
#         6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,  6,
# ...

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df[:10],labels=label_df[:10],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Kuldeep Yadav from Delhi Capitals is Not Out Maximum number of times

# %%
label_df=df.groupby('team')['Home_team_wickets'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby('team')['Home_team_wickets'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum Home_team_wickets is taken by Royal Challengers Bangalore
# 2. Mainimum Home_team_wickets is taken by Mumbai Indains.

# %%
label_df=df.groupby('team')['Away_team_wickets'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby('team')['Away_team_wickets'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum Away_team_wickets is taken by Lucknow Super Giants
# 2. Mainimum Away_team_wickets is taken by Rajasthan Royals

# %%
label_df=df.groupby('team')['Home_team_over'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby('team')['Home_team_over'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum Home_team_over is taken by Gujarat Titans
# 2. Mainimum Home_team_over is taken by Mumbai Indians.

# %%
label_df=df.groupby('team')['Away_team_over'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby('team')['Away_team_over'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum Away_team_over is of Royal Challengers Banglore
# 2. Mainimum Away_team_over is of Rajasthan Royals.

# %% [markdown]
# # Maximum Noballs are delivered by which bowler

# %%
no_ball_df=df.groupby('No_ball').get_group(1)

# %%
no_ball_df
# Out:
#       match_no           Batsman                         team  Run  Ball  4s  \
# 1            1      Devon Conway          Chennai Super Kings    1     6   0
# 2            1      Devon Conway          Chennai Super Kings    1     6   0
# 11           1         Moeen Ali          Chennai Super Kings   23    17   4
# 12           1         Moeen Ali          Chennai Super Kings   23    17   4
# 16           1        Ben Stokes          Chennai Super Kings    7     6   1
# ...        ...               ...                          ...  ...   ...  ..
# 6576        69  Suryakumar Yadav               Mumbai Indians   25    16   4
# 6592        70     Glenn Maxwell  Royal Challengers Bangalore   11     5   1
# 6598        70    Mahipal Lomror  Royal Challengers Bangalore    1     3   0
# 6610        70    Dinesh Karthik  Royal Challengers Bangalore    0     1   0
# 6616        70        Anuj Rawat  Royal Challengers Bangalore   23    15   1
#
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(no_ball_df['Bowler'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Observations:
# 1. Maximum NoBalls are delivered by Sandeep Sharma.
# 2. Minimum NoBalls are delivered by Kyle Mayers.

# %%
label_df=df.groupby(['Batsman','team','date_of_match'])['Run'].sum().sort_values(ascending=False)[:20].index

# %%
val_df=df.groupby(['Batsman','team','date_of_match'])['Run'].sum().sort_values(ascending=False)[:20].values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=df.groupby(['team'])['Home_team_run'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby(['team'])['Home_team_run'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum Home_team_run is of Mumbai Indians
# 2. Minimum Home_team_run is of  Delhi Capitals.

# %%
label_df=df.groupby(['team'])['Away_team_run'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby(['team'])['Away_team_run'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum Home_team_run is of Mumbai Indians
# 2. Minimum Home_team_run is of  Delhi Capitals.

# %%
label_df=df.groupby(['team'])['Home_team_wickets'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby(['team'])['Home_team_wickets'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum Home_team_wickets is of Royal Challengers Bangalore
# 2. Minimum Home_team_wickets is of  Mumbai Indians.

# %% [markdown]
# # Maximum number of wicket are taken by which bowler

# %%
label_df=df.groupby('Bowler')['wicket'].sum().sort_values(ascending=False).index

# %%
val_df=df.groupby('Bowler')['wicket'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,15))
plt.pie(x=val_df[:10],labels=label_df[:10],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum wickets is taken by Mohammed Shami

# %%
no_ball_df
# Out:
#       match_no           Batsman                         team  Run  Ball  4s  \
# 1            1      Devon Conway          Chennai Super Kings    1     6   0
# 2            1      Devon Conway          Chennai Super Kings    1     6   0
# 11           1         Moeen Ali          Chennai Super Kings   23    17   4
# 12           1         Moeen Ali          Chennai Super Kings   23    17   4
# 16           1        Ben Stokes          Chennai Super Kings    7     6   1
# ...        ...               ...                          ...  ...   ...  ..
# 6576        69  Suryakumar Yadav               Mumbai Indians   25    16   4
# 6592        70     Glenn Maxwell  Royal Challengers Bangalore   11     5   1
# 6598        70    Mahipal Lomror  Royal Challengers Bangalore    1     3   0
# 6610        70    Dinesh Karthik  Royal Challengers Bangalore    0     1   0
# 6616        70        Anuj Rawat  Royal Challengers Bangalore   23    15   1
#
# ...

# %% [markdown]
# # Matches conducted in cities

# %%
label_df=df['city'].value_counts().sort_values(ascending=False).index

# %%
val_df=df['city'].value_counts().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum match is conducted in Chennai.
# 2. Minimum match is conducted in Ahmedabad

# %% [markdown]
# # Maximum number of runs are given by which bowler

# %%
label_df=df.groupby(['Bowler','over','team'])['run'].sum().sort_values(ascending=False).index

# %%
val_df=df.groupby(['Bowler','over','team'])['run'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,15))
plt.pie(x=val_df[:10],labels=label_df[:10],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of runs are given by Varun Chakaravarthy in 4 overs

# %% [markdown]
# # Batsman scoring maximum runs on which venue

# %%
label_df=df.groupby(['Batsman','venue'])['Run'].sum().sort_values(ascending=False).index

# %%
val_df=df.groupby(['Batsman','venue'])['Run'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,15))
plt.pie(x=val_df[:10],labels=label_df[:10],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of runs are scored by Ruturaj Gaikwad at MA CHIDAMBARAM Stadium.

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %% [markdown]
# # Batsman facing maximum number of NO Balls

# %%
label_df=df.groupby(['Batsman','team','Bowler'])['No_ball'].sum().sort_values(ascending=False)[:10].index

# %%
val_df=df.groupby(['Batsman','team','Bowler'])['No_ball'].sum().sort_values(ascending=False)[:10].values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df[:15],labels=label_df[:15],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of no balls is faced by Abhishek Sharma and Rahul Tripathi.

# %%
label_df=df.groupby(['match_no','Batsman','team'])['Run'].mean().sort_values(ascending=False).index

# %%
val_df=df.groupby(['match_no','Batsman','team'])['Run'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df[:20],labels=label_df[:20],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of runs are scored by Sai Sudharsan of Gujarat Titans
# 2. Minimum number of runs are scored by KL Rahul of Lucknow Super Giants.

# %% [markdown]
# # Venue for Umpire 1

# %%
label_df=df.groupby('venue')['umpire1'].value_counts().sort_values(ascending=False).index

# %%
val_df=df.groupby('venue')['umpire1'].value_counts().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df[:10],labels=label_df[:10],data=df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Umpire 1 KN Anantha Padmanabhan has done umpiring at M.Chinnaswamy Stadium maximum number of times.

# %%
label_df=df.groupby(['umpire1','umpire2'])['venue'].value_counts().sort_values(ascending=False).index

# %%
val_df=df.groupby(['umpire1','umpire2'])['venue'].value_counts().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df[:10],labels=label_df[:10],autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # max score by Teams on different venue

# %%
label_df=df.groupby(['match_no','team','venue'])['Run'].sum().sort_values(ascending=False).index

# %%
val_df=df.groupby(['match_no','team','venue'])['Run'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(15,20))
plt.pie(x=val_df[:10],labels=label_df[:10],autopct="%1.2f%%")
plt.show()

# %%
sns.countplot(df['eliminator'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='eliminator', ylabel='count'>

# %%
match_1_df=df.groupby('match_no').get_group(1)

# %%
match_1_df
# Out:
#     match_no       Batsman                 team  Run  Ball  4s  6s  \
# 0          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1  Devon Conway  Chennai Super Kings    1     6   0   0
# ..       ...           ...                  ...  ...   ...  ..  ..
# 82         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 83         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 84         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 85         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 86         1   Rashid Khan       Gujarat Titans   10     3   1   1
#
#             out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# 0   Mohammed Shami            182                  5  ...              5
# ...

# %% [markdown]
# # Bowler with number of wickets

# %%
match_1_df.groupby(['Bowler','team'])['wicket'].sum().sort_values(ascending=False)
# Out:
# Bowler                  team
# Rajvardhan Hangargekar  Chennai Super Kings    24
# Alzarri Joseph          Gujarat Titans         12
# Mohammed Shami          Gujarat Titans         12
# Rashid Khan             Gujarat Titans         12
# Ravindra Jadeja         Chennai Super Kings     8
# Tushar Deshpande        Chennai Super Kings     8
# Joshua Little           Gujarat Titans          6
# Deepak Chahar           Chennai Super Kings     0
# Hardik Pandya           Gujarat Titans          0
# Mitchell Santner        Chennai Super Kings     0
# Yash Dayal              Gujarat Titans          0
# Name: wicket, dtype: int64

# %%
label_df=match_1_df.groupby(['Bowler','team'])['wicket'].sum().sort_values(ascending=False).index

# %%
val_df=match_1_df.groupby(['Bowler','team'])['wicket'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Rajvardhan Hangargekar has taken maximum number of wickets.

# %% [markdown]
# # Bowler with number of over

# %%
match_1_df.groupby(['Bowler','team'])['over'].sum().sort_values(ascending=False)
# Out:
# Bowler                  team
# Deepak Chahar           Chennai Super Kings    32.0
# Mitchell Santner        Chennai Super Kings    32.0
# Rajvardhan Hangargekar  Chennai Super Kings    32.0
# Ravindra Jadeja         Chennai Super Kings    32.0
# Tushar Deshpande        Chennai Super Kings    25.6
# Alzarri Joseph          Gujarat Titans         24.0
# Joshua Little           Gujarat Titans         24.0
# Mohammed Shami          Gujarat Titans         24.0
# Rashid Khan             Gujarat Titans         24.0
# Hardik Pandya           Gujarat Titans         18.0
# Yash Dayal              Gujarat Titans          6.0
# Name: over, dtype: float64

# %%
label_df=match_1_df.groupby(['Bowler','team'])['over'].sum().sort_values(ascending=False).index

# %%
val_df=match_1_df.groupby(['Bowler','team'])['over'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Batsman with number of 4s and 6s

# %%
match_1_df
# Out:
#     match_no       Batsman                 team  Run  Ball  4s  6s  \
# 0          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1  Devon Conway  Chennai Super Kings    1     6   0   0
# ..       ...           ...                  ...  ...   ...  ..  ..
# 82         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 83         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 84         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 85         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 86         1   Rashid Khan       Gujarat Titans   10     3   1   1
#
#             out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# 0   Mohammed Shami            182                  5  ...              5
# ...

# %%
match_1_df.groupby(['Batsman','team'])['4s'].sum().sort_values(ascending=False)
# Out:
# Batsman           team
# Moeen Ali         Chennai Super Kings    20
# Sai Sudharsan     Gujarat Titans         18
# Vijay Shankar     Gujarat Titans         12
# Wriddhiman Saha   Gujarat Titans         12
# Rahul Tewatia     Gujarat Titans          6
# Rashid Khan       Gujarat Titans          6
# Ben Stokes        Chennai Super Kings     5
# MS Dhoni          Chennai Super Kings     5
# Ambati Rayudu     Chennai Super Kings     0
# Devon Conway      Chennai Super Kings     0
# Hardik Pandya     Gujarat Titans          0
# Mitchell Santner  Chennai Super Kings     0
# Ravindra Jadeja   Chennai Super Kings     0
# Shivam Dube       Chennai Super Kings     0
# Name: 4s, dtype: int64

# %%
label_df=match_1_df.groupby(['Batsman','team'])['4s'].sum().sort_values(ascending=False).index

# %%
val_df=match_1_df.groupby(['Batsman','team'])['4s'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Batsman with maximum number of 4s in match 1 : Moeen Ali of Chennai Super Kings.

# %%
match_1_df.groupby(['Batsman','team'])['6s'].sum().sort_values(ascending=False)
# Out:
# Batsman           team
# Wriddhiman Saha   Gujarat Titans         12
# Rahul Tewatia     Gujarat Titans          6
# Rashid Khan       Gujarat Titans          6
# Vijay Shankar     Gujarat Titans          6
# Ambati Rayudu     Chennai Super Kings     5
# MS Dhoni          Chennai Super Kings     5
# Moeen Ali         Chennai Super Kings     5
# Shivam Dube       Chennai Super Kings     5
# Ben Stokes        Chennai Super Kings     0
# Devon Conway      Chennai Super Kings     0
# Hardik Pandya     Gujarat Titans          0
# Mitchell Santner  Chennai Super Kings     0
# Ravindra Jadeja   Chennai Super Kings     0
# Sai Sudharsan     Gujarat Titans          0
# Name: 6s, dtype: int64

# %%
label_df=match_1_df.groupby(['Batsman','team'])['6s'].sum().sort_values(ascending=False).index

# %%
val_df=match_1_df.groupby(['Batsman','team'])['6s'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Batsman with maximum number of 6s in IPL 2023 : Wriddhiman Saha of Gujarat Titans.

# %% [markdown]
# # Batsman with number of runs

# %%
match_1_df.groupby(['Batsman','team'])['Run'].sum().sort_values(ascending=False)
# Out:
# Batsman           team
# Vijay Shankar     Gujarat Titans         162
# Wriddhiman Saha   Gujarat Titans         150
# Sai Sudharsan     Gujarat Titans         132
# Moeen Ali         Chennai Super Kings    115
# Shivam Dube       Chennai Super Kings     95
# Rahul Tewatia     Gujarat Titans          90
# MS Dhoni          Chennai Super Kings     70
# Ambati Rayudu     Chennai Super Kings     60
# Rashid Khan       Gujarat Titans          60
# Hardik Pandya     Gujarat Titans          48
# Ben Stokes        Chennai Super Kings     35
# Devon Conway      Chennai Super Kings      5
# Mitchell Santner  Chennai Super Kings      5
# Ravindra Jadeja   Chennai Super Kings      5
# Name: Run, dtype: int64

# %%
label_df=match_1_df.groupby(['Batsman','team'])['Run'].sum().sort_values(ascending=False).index

# %%
val_df=match_1_df.groupby(['Batsman','team'])['Run'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Batsman with maximum number of runs in match 1 : Vijay Shankar of Gujarat Titans.
# 2. Batsman with maximum number of runs in match 1 : Ravindra Jadeja,Devon Conway and Mitchel of Chennai Super kings.

# %% [markdown]
# # Batsman with number of Balls

# %%
match_1_df.groupby(['Batsman','team'])['Ball'].sum().sort_values(ascending=False)
# Out:
# Batsman           team
# Vijay Shankar     Gujarat Titans         126
# Sai Sudharsan     Gujarat Titans         102
# Wriddhiman Saha   Gujarat Titans          96
# Shivam Dube       Chennai Super Kings     90
# Moeen Ali         Chennai Super Kings     85
# Rahul Tewatia     Gujarat Titans          84
# Hardik Pandya     Gujarat Titans          66
# Ambati Rayudu     Chennai Super Kings     60
# MS Dhoni          Chennai Super Kings     35
# Ben Stokes        Chennai Super Kings     30
# Devon Conway      Chennai Super Kings     30
# Rashid Khan       Gujarat Titans          18
# Mitchell Santner  Chennai Super Kings     15
# Ravindra Jadeja   Chennai Super Kings     10
# Name: Ball, dtype: int64

# %%
label_df=match_1_df.groupby(['Batsman','team'])['Ball'].sum().sort_values(ascending=False).index

# %%
val_df=match_1_df.groupby(['Batsman','team'])['Ball'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Batsman facing maximum number of balls in match  1: Vijay Shankar of Gujarat Titans
# 2. Batsman facing minimum number of balls in match  1: Ravindra Jadeja of Chennai Super Kings.

# %%
match_1_df
# Out:
#     match_no       Batsman                 team  Run  Ball  4s  6s  \
# 0          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1  Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1  Devon Conway  Chennai Super Kings    1     6   0   0
# ..       ...           ...                  ...  ...   ...  ..  ..
# 82         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 83         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 84         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 85         1   Rashid Khan       Gujarat Titans   10     3   1   1
# 86         1   Rashid Khan       Gujarat Titans   10     3   1   1
#
#             out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# 0   Mohammed Shami            182                  5  ...              5
# ...

# %%
Chennai_Super_ings_df=match_1_df.groupby('team').get_group('Chennai Super Kings')

# %%
Chennai_Super_ings_df
# Out:
#     match_no           Batsman                 team  Run  Ball  4s  6s  \
# 0          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 15         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# 16         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# ...

# %%
label_df=Chennai_Super_ings_df.groupby('Bowler')['ECO'].mean().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby('Bowler')['ECO'].mean().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Bowler with  maximum ECO rate : Tushar Deshpande.
# 2. Bowler with  minimum ECO rate : Ravindra Jadeja.

# %%
label_df=Chennai_Super_ings_df.groupby('Bowler')['No_ball'].sum().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby('Bowler')['No_ball'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
label_df=Chennai_Super_ings_df.groupby('Bowler')['over'].sum().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby('Bowler')['over'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of balls are delivered by Deepak Chahar,Mitchell Santner and Rajvardhan
# 2. Minimum number of balls are delivered by Tushar Deshpande.

# %%
label_df=Chennai_Super_ings_df.groupby('Bowler')['wicket'].sum().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby('Bowler')['wicket'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of wickets are taken by Rajvardhan Hangargekar of Chennai Super kings.

# %%
label_df=Chennai_Super_ings_df.groupby('Bowler')['run'].sum().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby('Bowler')['run'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Maximum number of run are given by Tushar Deshpande of Chennai Super kings.
# 2. Minimum number of run are given by Ravindra Jadeja of Chennai Super kings.

# %% [markdown]
# # Bowler giving max 6s and 4s

# %%
Chennai_Super_ings_df
# Out:
#     match_no           Batsman                 team  Run  Ball  4s  6s  \
# 0          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 15         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# 16         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# ...

# %%
label_df=Chennai_Super_ings_df.groupby('Bowler')['4s'].sum().index

# %%
val_df=Chennai_Super_ings_df.groupby('Bowler')['4s'].sum().values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. All 5 bolwers given equal number of 4s in their over.

# %%
label_df=Chennai_Super_ings_df.groupby('Bowler')['6s'].sum().index

# %%
val_df=Chennai_Super_ings_df.groupby('Bowler')['6s'].sum().values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. All 5 bolwers given equal number of 6s in their over.

# %%
Chennai_Super_ings_df['Home_team_run'].value_counts()
# Out:
# 182    40
# Name: Home_team_run, dtype: int64

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
sns.countplot(df['eliminator'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='eliminator', ylabel='count'>

# %%
df.columns
# Out:
# Index(['match_no', 'Batsman', 'team', 'Run', 'Ball', '4s', '6s', 'out_by',
#        'Home_team_run', 'Home_team_wickets', 'Home_team_over', 'Away_team_run',
#        'Away_team_wickets', 'Away_team_over', 'city', 'date_of_match', 'venue',
#        'Home_team', 'Away_team', 'toss_winner', 'winner', 'man_of_the_match',
#        'result', 'result_margin', 'eliminator', 'umpire1', 'umpire2', 'Bowler',
#        'over', 'run', 'wicket', 'No_ball', 'ECO'],
#       dtype='object')

# %% [markdown]
# # Man of the Match

# %%
Chennai_Super_ings_df['man_of_the_match'].value_counts()
# Out:
# Rashid Khan    40
# Name: man_of_the_match, dtype: int64

# %% [markdown]
# # Observations:
# 1. Man of the match for Chennai Super kings for match 1 : Rashid Khan

# %%
Chennai_Super_ings_df
# Out:
#     match_no           Batsman                 team  Run  Ball  4s  6s  \
# 0          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 15         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# 16         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# ...

# %%
Chennai_Super_ings_df
# Out:
#     match_no           Batsman                 team  Run  Ball  4s  6s  \
# 0          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 15         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# 16         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# ...

# %%
label_df=Chennai_Super_ings_df.groupby(['Batsman','out_by']).size().index

# %%
val_df=Chennai_Super_ings_df.groupby(['Batsman','out_by']).size().values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
Chennai_Super_ings_df
# Out:
#     match_no           Batsman                 team  Run  Ball  4s  6s  \
# 0          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 15         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# 16         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# ...

# %%
label_df=Chennai_Super_ings_df.groupby(['Batsman','out_by'])['Run'].sum().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby(['Batsman','out_by'])['Run'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Rashid Khan out Moeen Ali maximum number of time.

# %%
label_df=Chennai_Super_ings_df.groupby(['Batsman','out_by'])['4s'].sum().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby(['Batsman','out_by'])['4s'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Observations:
# 1. Moeen Ali scored maximun number of 4s out by Rashid Khan.

# %%
label_df=Chennai_Super_ings_df.groupby(['Batsman','out_by'])['6s'].sum().sort_values(ascending=False).index

# %%
val_df=Chennai_Super_ings_df.groupby(['Batsman','out_by'])['6s'].sum().sort_values(ascending=False).values

# %%
plt.figure(figsize=(10,10))
plt.pie(x=val_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
Chennai_Super_ings_df
# Out:
#     match_no           Batsman                 team  Run  Ball  4s  6s  \
# 0          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 15         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# 16         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# ...

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
Chennai_Super_ings_df
# Out:
#     match_no           Batsman                 team  Run  Ball  4s  6s  \
# 0          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 1          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 2          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 3          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 4          1      Devon Conway  Chennai Super Kings    1     6   0   0
# 10         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 11         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 12         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 13         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 14         1         Moeen Ali  Chennai Super Kings   23    17   4   1
# 15         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# 16         1        Ben Stokes  Chennai Super Kings    7     6   1   0
# ...

# %%
Chennai_Super_ings_df['Home_team_wickets'].value_counts()
# Out:
# 5    40
# Name: Home_team_wickets, dtype: int64

# %%
Chennai_Super_ings_df['Away_team_wickets'].value_counts()
# Out:
# 7    40
# Name: Away_team_wickets, dtype: int64

# %% [markdown]
# # Target Score set by DLS

# %%
eliminator_DLS_df=df.groupby('eliminator').get_group('DLS')

# %%
eliminator_DLS_df
# Out:
#      match_no            Batsman                   team  Run  Ball  4s  6s  \
# 87          2  Prabhsimran Singh           Punjab Kings   23    12   2   2
# 88          2  Prabhsimran Singh           Punjab Kings   23    12   2   2
# 89          2  Prabhsimran Singh           Punjab Kings   23    12   2   2
# 90          2  Prabhsimran Singh           Punjab Kings   23    12   2   2
# 91          2  Prabhsimran Singh           Punjab Kings   23    12   2   2
# ..        ...                ...                    ...  ...   ...  ..  ..
# 176         2       Sunil Narine  Kolkata Knight Riders    7     2   0   1
# 177         2       Sunil Narine  Kolkata Knight Riders    7     2   0   1
# 178         2       Sunil Narine  Kolkata Knight Riders    7     2   0   1
# 179         2       Sunil Narine  Kolkata Knight Riders    7     2   0   1
# 180         2       Sunil Narine  Kolkata Knight Riders    7     2   0   1
#
# ...

# %%
eliminator_DLS_df.groupby(['match_no','team'])['Run'].sum()
# Out:
# match_no  team
# 2         Kolkata Knight Riders    700
#           Punjab Kings             679
# Name: Run, dtype: int64

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...

# %%
df.columns
# Out:
# Index(['match_no', 'Batsman', 'team', 'Run', 'Ball', '4s', '6s', 'out_by',
#        'Home_team_run', 'Home_team_wickets', 'Home_team_over', 'Away_team_run',
#        'Away_team_wickets', 'Away_team_over', 'city', 'date_of_match', 'venue',
#        'Home_team', 'Away_team', 'toss_winner', 'winner', 'man_of_the_match',
#        'result', 'result_margin', 'eliminator', 'umpire1', 'umpire2', 'Bowler',
#        'over', 'run', 'wicket', 'No_ball', 'ECO'],
#       dtype='object')

# %%
df
# Out:
#       match_no        Batsman                 team  Run  Ball  4s  6s  \
# 0            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 2            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 3            1   Devon Conway  Chennai Super Kings    1     6   0   0
# 4            1   Devon Conway  Chennai Super Kings    1     6   0   0
# ...        ...            ...                  ...  ...   ...  ..  ..
# 6646        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6647        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6648        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6649        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
# 6650        70  Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#               out_by  Home_team_run  Home_team_wickets  ...  result_margin  \
# ...
